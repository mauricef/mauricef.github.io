# %%
# %pip install git+https://github.com/mauricef/halite-iv-jax.git@ef53aabb558bc7b3dd2d640a04c106d9e2083108

# %% [markdown]
# # Python Agents

# %%
from kaggle_environments import make
from halite_jax.py_agents import *
# Out:
# Loading environment football failed: No module named 'gfootball'

# %% [markdown]
# These are agents copied from other peoples notebooks and submissions
#
# - [agent_1](https://www.kaggle.com/c/halite/discussion/183543)
# - [agent_2](https://www.kaggle.com/c/halite/discussion/186032)
# - [agent_3](https://www.kaggle.com/c/halite/discussion/183727)
# - [agent_4](https://www.kaggle.com/c/halite/discussion/185865)
# - [agent_5](https://www.kaggle.com/alexisbcook/getting-started-with-halite)

# %%
env = make("halite", configuration=dict(episodeSteps=25))
_ = env.reset(4)
_ = env.run([agent_1, agent_2, agent_3, agent_4])
env.render(mode='ipython', width=800, height=700)
# Out:
# INFO:root:Number of vulnerable ships: 0
# INFO:root:Planning to place the next shipyard at (5, 5)
# INFO:root:*** Ship type breakdown for step 0 (5000 halite) (avg halite: 112.2279792746114) (ship advantage: 0) ***
# INFO:root:CONVERTING: 1 (100.0%)
# INFO:root:Number of vulnerable ships: 0
# INFO:root:Number of vulnerable ships: 0
# INFO:root:*** Ship type breakdown for step 2 (4000 halite) (avg halite: 116.762) (ship advantage: 0) ***
# INFO:root:MINING: 1 (100.0%)
# INFO:root:Number of vulnerable ships: 0
# INFO:root:*** Ship type breakdown for step 3 (3500 halite) (avg halite: 119.09615544041453) (ship advantage: 0) ***
# INFO:root:MINING: 2 (100.0%)
# INFO:root:Number of vulnerable ships: 0
# INFO:root:*** Ship type breakdown for step 4 (3000 halite) (avg halite: 121.46224352331608) (ship advantage: 0) ***
# INFO:root:MINING: 3 (100.0%)
# INFO:root:Number of vulnerable ships: 0
# ...
